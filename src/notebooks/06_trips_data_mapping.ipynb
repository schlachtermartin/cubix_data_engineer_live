# %%
import os,  pandas as pd, requests
from datetime import datetime
from dateutil.relativedelta import relativedelta
pd.set_option("display.max_columns", 30)

# %%
current_datetime = datetime.now() - relativedelta(months=2)

formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = f"http://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formatted_datetime}T00:00:00' AND trip_start_timestamp <= '{formatted_datetime}T23:59:59'&$limit=30000"

headers = {"X-App-Token":os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url)

data = response.json()

# %%
#19.214 rows

len(data)
# Out:
# 14377

# %%
taxi_trips = pd.DataFrame(data)

# %%
taxi_trips.head(6)
# Out:
#                                     trip_id  \
# 0  211363e06f9055c0a07d9d8eccb50ee850aa8883
# 1  2132ccd8dad201af9e286c891abbe778544c6ce9
# 2  2700db3acf29ba91393e368447a24dff2b1e8cb0
# 3  44b02e972c071a85fd3047de663ef7a51c6eb126
# 4  490985cfa6222e118c9e2ac9f6c9a260d7faf260
# 5  4d93a5d508f76ad7f583e97dbe8785a7b212ecf7
#
#                                              taxi_id     trip_start_timestamp  \
# 0  8d75a4e15682364840d85e0f9f954e98b2703f4e252e88...  2024-10-05T23:45:00.000
# 1  3618045f9110d4d88482266ade23659c1a50d32ac37f20...  2024-10-05T23:45:00.000
# 2  a39edfa6e2ec6209ece046221d25bdb4c4fee327de239a...  2024-10-05T23:45:00.000
# 3  c018902b2cca3d3d34af3de6d486f3a7dd7af724d85ce5...  2024-10-05T23:45:00.000
# 4  14b8965581705a67e75b3fadeb43570909052a0f646341...  2024-10-05T23:45:00.000
# 5  76ada519383bfceac02f12639c38c26cf5613295999b69...  2024-10-05T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area  \
# 0  2024-10-06T00:00:00.000         1200       12.9                    76
# 1  2024-10-06T00:00:00.000          900        3.8                     6
# 2  2024-10-06T00:00:00.000          452       3.84                    76
# 3  2024-10-06T00:00:00.000          390       1.53                    28
# 4  2024-10-06T00:15:00.000         1346      10.52                    76
# 5  2024-10-06T00:15:00.000         1288      16.64                    28
#
#   dropoff_community_area   fare  tips tolls extras trip_total payment_type  \
# 0                     22  33.25  7.55     0      4       44.8  Credit Card
# 1                     24     13     0     0      0         13      Unknown
# 2                     10     12   5.5     0     15         33  Credit Card
# 3                     33   7.25     0     0      0       7.25         Cash
# 4                    NaN  28.25  6.75     0      5       40.5  Credit Card
# 5                     75  39.63     0     0      0      39.63         Cash
#
#                         company pickup_centroid_latitude  \
# 0     Taxi Affiliation Services             41.980264315
# 1     Taxi Affiliation Services             41.944226601
# 2                      Sun Taxi             41.980264315
# 3  Taxicab Insurance Agency Llc             41.874005383
# 4                  City Service             41.980264315
# 5                     Flash Cab             41.874005383
#
#   pickup_centroid_longitude  \
# 0             -87.913624596
# 1             -87.655998182
# 2             -87.913624596
# 3              -87.66351755
# 4             -87.913624596
# 5              -87.66351755
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.91362459...
# 1  {'type': 'Point', 'coordinates': [-87.65599818...
# 2  {'type': 'Point', 'coordinates': [-87.91362459...
# 3  {'type': 'Point', 'coordinates': [-87.66351754...
# 4  {'type': 'Point', 'coordinates': [-87.91362459...
# 5  {'type': 'Point', 'coordinates': [-87.66351754...
#
#   dropoff_centroid_latitude dropoff_centroid_longitude  \
# 0               41.92276062              -87.699155343
# 1              41.901206994              -87.676355989
# 2              41.985015101              -87.804532006
# 3              41.857183858              -87.620334624
# 4                       NaN                        NaN
# 5              41.689729914              -87.669054403
#
#                            dropoff_centroid_location pickup_census_tract  \
# 0  {'type': 'Point', 'coordinates': [-87.69915534...                 NaN
# 1  {'type': 'Point', 'coordinates': [-87.67635598...                 NaN
# 2  {'type': 'Point', 'coordinates': [-87.80453200...                 NaN
# 3  {'type': 'Point', 'coordinates': [-87.62033462...                 NaN
# 4                                                NaN                 NaN
# 5  {'type': 'Point', 'coordinates': [-87.66905440...                 NaN
#
#   dropoff_census_tract
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14377 entries, 0 to 14376
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     14377 non-null  object
#  1   taxi_id                     14377 non-null  object
#  2   trip_start_timestamp        14377 non-null  object
#  3   trip_end_timestamp          14377 non-null  object
#  4   trip_seconds                14373 non-null  object
#  5   trip_miles                  14377 non-null  object
#  6   pickup_community_area       14061 non-null  object
#  7   dropoff_community_area      13247 non-null  object
#  8   fare                        14327 non-null  object
#  9   tips                        14327 non-null  object
#  10  tolls                       14327 non-null  object
#  11  extras                      14327 non-null  object
#  12  trip_total                  14327 non-null  object
#  13  payment_type                14377 non-null  object
#  14  company                     14377 non-null  object
#  15  pickup_centroid_latitude    14066 non-null  object
#  16  pickup_centroid_longitude   14066 non-null  object
#  17  pickup_centroid_location    14066 non-null  object
#  18  dropoff_centroid_latitude   13302 non-null  object
#  19  dropoff_centroid_longitude  13302 non-null  object
#  20  dropoff_centroid_location   13302 non-null  object
#  21  pickup_census_tract         5460 non-null   object
#  22  dropoff_census_tract        5327 non-null   object
# dtypes: object(23)
# memory usage: 2.5+ MB

# %%
taxi_trips.describe()
# Out:
#                                          trip_id  \
# count                                      14377
# unique                                     14377
# top     053dd544a48280d343d72bfb65468b4e6e6d9138
# freq                                           1
#
#                                                   taxi_id  \
# count                                               14377
# unique                                               2064
# top     4fd6cc40972b7fd3e026723f0fc4928d7f3159ea0e0822...
# freq                                                   38
#
#            trip_start_timestamp       trip_end_timestamp trip_seconds  \
# count                     14377                    14377        14373
# unique                       96                      107         3430
# top     2024-10-05T15:15:00.000  2024-10-05T16:15:00.000            0
# freq                        284                      287          214
#
#        trip_miles pickup_community_area dropoff_community_area   fare   tips  \
# count       14377                 14061                  13247  14327  14327
# unique       2317                    77                     77   1246    947
# top             0                     8                      8      9      0
# freq         1537                  3298                   3477    531   7723
#
#         tolls extras trip_total payment_type    company  \
# count   14327  14327      14327        14377      14377
# unique     16    174       2229            7         29
# top         0      0       3.25  Credit Card  Flash Cab
# freq    14248   8738        212         5403       3206
#
#        pickup_centroid_latitude pickup_centroid_longitude  \
# count                     14066                     14066
# unique                      132                       132
# top                41.899602111             -87.633308037
# freq                       1798                      1798
#
#                                  pickup_centroid_location  \
# count                                               14066
# unique                                                132
# top     {'type': 'Point', 'coordinates': [-87.63330803...
# freq                                                 1798
#
#        dropoff_centroid_latitude dropoff_centroid_longitude  \
# count                      13302                      13302
# unique                       151                        151
# top                 41.899602111              -87.633308037
# freq                        1480                       1480
#
#                                 dropoff_centroid_location pickup_census_tract  \
# count                                               13302                5460
# unique                                                151                  55
# top     {'type': 'Point', 'coordinates': [-87.63330803...         17031980000
# freq                                                 1480                1545
#
#        dropoff_census_tract
# count                  5327
# unique                   76
# top             17031320100
# freq                    702

# %% [markdown]
# ## Transformation: deal with NaN values

# %%
taxi_trips.drop(["pickup_census_tract", "dropoff_census_tract"], axis=1, inplace=True)

# %%
taxi_trips.drop(["pickup_centroid_location", "dropoff_centroid_location"], axis=1, inplace=True)

# %%
taxi_trips.dropna(inplace=True)

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13066 entries, 0 to 14376
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     13066 non-null  object
#  1   taxi_id                     13066 non-null  object
#  2   trip_start_timestamp        13066 non-null  object
#  3   trip_end_timestamp          13066 non-null  object
#  4   trip_seconds                13066 non-null  object
#  5   trip_miles                  13066 non-null  object
#  6   pickup_community_area       13066 non-null  object
#  7   dropoff_community_area      13066 non-null  object
#  8   fare                        13066 non-null  object
#  9   tips                        13066 non-null  object
#  10  tolls                       13066 non-null  object
#  11  extras                      13066 non-null  object
#  12  trip_total                  13066 non-null  object
#  13  payment_type                13066 non-null  object
#  14  company                     13066 non-null  object
#  15  pickup_centroid_latitude    13066 non-null  object
#  16  pickup_centroid_longitude   13066 non-null  object
#  17  dropoff_centroid_latitude   13066 non-null  object
#  18  dropoff_centroid_longitude  13066 non-null  object
# dtypes: object(19)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Trasformation: renaming

# %%
taxi_trips.rename(columns={"pickup_community_area": "pickup_community_area_id",
                           "dropoff_community_area": "dropoff_community_area_id"}, inplace=True)

# %%
taxi_trips.columns
# Out:
# Index(['trip_id', 'taxi_id', 'trip_start_timestamp', 'trip_end_timestamp',
#        'trip_seconds', 'trip_miles', 'pickup_community_area_id',
#        'dropoff_community_area_id', 'fare', 'tips', 'tolls', 'extras',
#        'trip_total', 'payment_type', 'company', 'pickup_centroid_latitude',
#        'pickup_centroid_longitude', 'dropoff_centroid_latitude',
#        'dropoff_centroid_longitude'],
#       dtype='object')

# %% [markdown]
# ### Transformation: create helper column for weather

# %%
taxi_trips["trip_start_timestamp"] = pd.to_datetime(taxi_trips["trip_start_timestamp"])

# %%
taxi_trips["datetime_for_weather"] = taxi_trips["trip_start_timestamp"].dt.floor("h")

# %%
taxi_trips["datetime_for_weather"]
# Out:
# 0       2024-10-05 23:00:00
# 1       2024-10-05 23:00:00
# 2       2024-10-05 23:00:00
# 3       2024-10-05 23:00:00
# 5       2024-10-05 23:00:00
#                 ...
# 14372   2024-10-05 00:00:00
# 14373   2024-10-05 00:00:00
# 14374   2024-10-05 00:00:00
# 14375   2024-10-05 00:00:00
# 14376   2024-10-05 00:00:00
# Name: datetime_for_weather, Length: 13066, dtype: datetime64[ns]

# %% [markdown]
# #### Check joining the trips and the weather data

# %%
# Get weather data, and create a dataframe out of it.

current_datetime = datetime.now() - relativedelta(months=2)
formatted_datetime = current_datetime.strftime("%Y-%m-%d")

url = "https://archive-api.open-meteo.com/v1/era5"

params = {
    "latitude":41.85,
    "longitude": -87.65,
    "start_date": formatted_datetime,
    "end_date": formatted_datetime,
    "hourly": "temperature_2m,wind_speed_10m,precipitation,rain"
}

response = requests.get(url, params=params)

weather_data = response.json()

weather_data_filtered = {
    "datetime":weather_data['hourly']['time'],
    "tempretaure":weather_data['hourly']['temperature_2m'],
    "wind_speed":weather_data['hourly']['wind_speed_10m'],
    "rain":weather_data['hourly']['rain'],
    "precipitation":weather_data['hourly']['precipitation']
}

weather_df = pd.DataFrame(weather_data_filtered)

weather_df["datetime"] = pd.to_datetime(weather_df["datetime"])

weather_df.head()
# Out:
#              datetime  tempretaure  wind_speed  rain  precipitation
# 0 2024-10-05 00:00:00         15.6        18.8   0.0            0.0
# 1 2024-10-05 01:00:00         15.6        18.7   0.0            0.0
# 2 2024-10-05 02:00:00         15.4        17.3   0.0            0.0
# 3 2024-10-05 03:00:00         15.1        14.6   0.0            0.0
# 4 2024-10-05 04:00:00         15.0        15.2   0.0            0.0

# %%
taxi_trips_with_weather = taxi_trips.merge(weather_df, left_on="datetime_for_weather", right_on="datetime")

# %%
taxi_trips_with_weather.head()
# Out:
#                                     trip_id  \
# 0  211363e06f9055c0a07d9d8eccb50ee850aa8883
# 1  2132ccd8dad201af9e286c891abbe778544c6ce9
# 2  2700db3acf29ba91393e368447a24dff2b1e8cb0
# 3  44b02e972c071a85fd3047de663ef7a51c6eb126
# 4  4d93a5d508f76ad7f583e97dbe8785a7b212ecf7
#
#                                              taxi_id trip_start_timestamp  \
# 0  8d75a4e15682364840d85e0f9f954e98b2703f4e252e88...  2024-10-05 23:45:00
# 1  3618045f9110d4d88482266ade23659c1a50d32ac37f20...  2024-10-05 23:45:00
# 2  a39edfa6e2ec6209ece046221d25bdb4c4fee327de239a...  2024-10-05 23:45:00
# 3  c018902b2cca3d3d34af3de6d486f3a7dd7af724d85ce5...  2024-10-05 23:45:00
# 4  76ada519383bfceac02f12639c38c26cf5613295999b69...  2024-10-05 23:45:00
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area_id  \
# 0  2024-10-06T00:00:00.000         1200       12.9                       76
# 1  2024-10-06T00:00:00.000          900        3.8                        6
# 2  2024-10-06T00:00:00.000          452       3.84                       76
# 3  2024-10-06T00:00:00.000          390       1.53                       28
# 4  2024-10-06T00:15:00.000         1288      16.64                       28
#
#   dropoff_community_area_id   fare  tips tolls extras trip_total payment_type  \
# 0                        22  33.25  7.55     0      4       44.8  Credit Card
# 1                        24     13     0     0      0         13      Unknown
# 2                        10     12   5.5     0     15         33  Credit Card
# 3                        33   7.25     0     0      0       7.25         Cash
# 4                        75  39.63     0     0      0      39.63         Cash
#
#                         company pickup_centroid_latitude  \
# 0     Taxi Affiliation Services             41.980264315
# 1     Taxi Affiliation Services             41.944226601
# 2                      Sun Taxi             41.980264315
# 3  Taxicab Insurance Agency Llc             41.874005383
# 4                     Flash Cab             41.874005383
#
#   pickup_centroid_longitude dropoff_centroid_latitude  \
# 0             -87.913624596               41.92276062
# 1             -87.655998182              41.901206994
# 2             -87.913624596              41.985015101
# 3              -87.66351755              41.857183858
# 4              -87.66351755              41.689729914
#
#   dropoff_centroid_longitude datetime_for_weather            datetime  \
# 0              -87.699155343  2024-10-05 23:00:00 2024-10-05 23:00:00
# 1              -87.676355989  2024-10-05 23:00:00 2024-10-05 23:00:00
# 2              -87.804532006  2024-10-05 23:00:00 2024-10-05 23:00:00
# 3              -87.620334624  2024-10-05 23:00:00 2024-10-05 23:00:00
# 4              -87.669054403  2024-10-05 23:00:00 2024-10-05 23:00:00
#
#    tempretaure  wind_speed  rain  precipitation
# 0         24.4        25.3   0.0            0.0
# 1         24.4        25.3   0.0            0.0
# 2         24.4        25.3   0.0            0.0
# 3         24.4        25.3   0.0            0.0
# 4         24.4        25.3   0.0            0.0

# %% [markdown]
# ### Transformation: Data type conversions

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13066 entries, 0 to 14376
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     13066 non-null  object
#  1   taxi_id                     13066 non-null  object
#  2   trip_start_timestamp        13066 non-null  datetime64[ns]
#  3   trip_end_timestamp          13066 non-null  object
#  4   trip_seconds                13066 non-null  object
#  5   trip_miles                  13066 non-null  object
#  6   pickup_community_area_id    13066 non-null  object
#  7   dropoff_community_area_id   13066 non-null  object
#  8   fare                        13066 non-null  object
#  9   tips                        13066 non-null  object
#  10  tolls                       13066 non-null  object
#  11  extras                      13066 non-null  object
#  12  trip_total                  13066 non-null  object
#  13  payment_type                13066 non-null  object
#  14  company                     13066 non-null  object
#  15  pickup_centroid_latitude    13066 non-null  object
#  16  pickup_centroid_longitude   13066 non-null  object
#  17  dropoff_centroid_latitude   13066 non-null  object
#  18  dropoff_centroid_longitude  13066 non-null  object
#  19  datetime_for_weather        13066 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(18)
# memory usage: 2.1+ MB

# %%
taxi_trips.head(1)
# Out:
#                                     trip_id  \
# 0  211363e06f9055c0a07d9d8eccb50ee850aa8883
#
#                                              taxi_id trip_start_timestamp  \
# 0  8d75a4e15682364840d85e0f9f954e98b2703f4e252e88...  2024-10-05 23:45:00
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area_id  \
# 0  2024-10-06T00:00:00.000         1200       12.9                       76
#
#   dropoff_community_area_id   fare  tips tolls extras trip_total payment_type  \
# 0                        22  33.25  7.55     0      4       44.8  Credit Card
#
#                      company pickup_centroid_latitude  \
# 0  Taxi Affiliation Services             41.980264315
#
#   pickup_centroid_longitude dropoff_centroid_latitude  \
# 0             -87.913624596               41.92276062
#
#   dropoff_centroid_longitude datetime_for_weather
# 0              -87.699155343  2024-10-05 23:00:00

# %%
data_types = {
    "trip_end_timestamp": "datetime64[ns]",
    "trip_seconds": "int32",
    "trip_miles": "float",
    "pickup_community_area_id": "int8",
    "dropoff_community_area_id": "int8",
    "fare": "float",
    "tips": "float",
    "tolls": "float",
    "extras": "float",
    "trip_total": "float",
}

taxi_trips = taxi_trips.astype(data_types)

# %%
taxi_trips.describe()
# Out:
#                 trip_start_timestamp             trip_end_timestamp  \
# count                          13066                          13066
# mean   2024-10-05 14:37:29.862237696  2024-10-05 14:58:48.432572928
# min              2024-10-05 00:00:00            2024-10-05 00:00:00
# 25%              2024-10-05 11:15:00            2024-10-05 11:45:00
# 50%              2024-10-05 15:00:00            2024-10-05 15:30:00
# 75%              2024-10-05 18:30:00            2024-10-05 19:00:00
# max              2024-10-05 23:45:00            2024-10-06 13:30:00
# std                              NaN                            NaN
#
#        trip_seconds    trip_miles  pickup_community_area_id  \
# count  13066.000000  13066.000000              13066.000000
# mean    1276.351217      6.459567                 33.454615
# min        0.000000      0.000000                  1.000000
# 25%      493.000000      1.080000                  8.000000
# 50%      909.000000      3.080000                 32.000000
# 75%     1697.750000     11.337500                 53.000000
# max    85403.000000    154.100000                 77.000000
# std     1511.101593      7.006857                 25.715949
#
#        dropoff_community_area_id          fare          tips         tolls  \
# count               13066.000000  13066.000000  13066.000000  13066.000000
# mean                   25.489897     22.360973      2.633567      0.006536
# min                     1.000000      0.000000      0.000000      0.000000
# 25%                     8.000000      8.750000      0.000000      0.000000
# 50%                    28.000000     15.250000      0.000000      0.000000
# 75%                    33.000000     32.000000      3.900000      0.000000
# max                    77.000000   3025.000000     90.000000     10.000000
# std                    20.251207     35.884398      4.102311      0.164909
#
#              extras    trip_total           datetime_for_weather
# count  13066.000000  13066.000000                          13066
# mean       1.404911     26.593688  2024-10-05 14:15:13.638450944
# min        0.000000      0.000000            2024-10-05 00:00:00
# 25%        0.000000     10.750000            2024-10-05 11:00:00
# 50%        0.000000     18.250000            2024-10-05 15:00:00
# 75%        1.500000     35.750000            2024-10-05 18:00:00
# max       64.000000   3025.000000            2024-10-05 23:00:00
# std        3.333040     37.777604                            NaN

# %% [markdown]
# ### Memory usage

# %%
taxi_trips.memory_usage(deep=True).sum()
# Out:
# np.int64(9408023)

# %% [markdown]
# #### Sanity checks

# %%
taxi_trips[taxi_trips['trip_end_timestamp'] == taxi_trips['trip_end_timestamp'].max()]
# Out:
#                                        trip_id  \
# 8286  4d20e04221836361728fd93b87e16a6b62e86dad
#
#                                                 taxi_id trip_start_timestamp  \
# 8286  931225a382fc38a75212f9d358439aec0d9b50fdaf32ad...  2024-10-05 14:00:00
#
#       trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 8286 2024-10-06 13:30:00         85403        0.11                        30
#
#       dropoff_community_area_id  fare  tips  tolls  extras  trip_total  \
# 8286                         30   3.5   0.0    0.0     0.0         3.5
#
#      payment_type    company pickup_centroid_latitude  \
# 8286         Cash  Flash Cab             41.839086906
#
#      pickup_centroid_longitude dropoff_centroid_latitude  \
# 8286             -87.714003807              41.839086906
#
#      dropoff_centroid_longitude datetime_for_weather
# 8286              -87.714003807  2024-10-05 14:00:00

# %% [markdown]
# ### Data Modeling

# %%
payment_type_master = taxi_trips["payment_type"].drop_duplicates().reset_index(drop=True)

payment_type_master = pd.DataFrame(
    {
        "payment_type_id": range(1, len(payment_type_master) + 1),
        "payment_type": payment_type_master
    }
)
payment_type_master
# Out:
#    payment_type_id payment_type
# 0                1  Credit Card
# 1                2      Unknown
# 2                3         Cash
# 3                4       Mobile
# 4                5       Prcard
# 5                6    No Charge
# 6                7      Dispute

# %%
company_master = taxi_trips["company"].drop_duplicates().reset_index(drop=True)

company_master = pd.DataFrame(
    {
        "company_type_id": range(1, len(company_master) + 1),
        "company": company_master
    }
)
company_master
# Out:
#     company_type_id                               company
# 0                 1             Taxi Affiliation Services
# 1                 2                              Sun Taxi
# 2                 3          Taxicab Insurance Agency Llc
# 3                 4                             Flash Cab
# 4                 5          Tac - Yellow Cab Association
# 5                 6                            Globe Taxi
# 6                 7          Blue Ribbon Taxi Association
# 7                 8                          City Service
# 8                 9                           5 Star Taxi
# 9                10                  Chicago Independents
# 10               11               Choice Taxi Association
# 11               12        Tac - American United Dispatch
# 12               13           Choice Taxi Association Inc
# 13               14         Chicago City Taxi Association
# 14               15         Taxicab Insurance Agency, LLC
# 15               16                      Medallion Leasin
# 16               17            Tac - Checker Cab Dispatch
# 17               18                           Wolley Taxi
# 18               19                       Chicago Taxicab
# 19               20          4053 - 40193 Adwar H. Nikola
# 20               21         312 Medallion Management Corp
# 21               22                             U Taxicab
# 22               23  Patriot Taxi Dba Peace Taxi Associat
# 23               24                               Top Cab
# 24               25                            Setare Inc
# 25               26                 Koam Taxi Association
# 26               27               2733 - 74600 Benny Jona
# 27               28           6574 - Babylon Express Inc.

# %%
taxi_trips[["payment_type", "company"]]
# Out:
#       payment_type                       company
# 0      Credit Card     Taxi Affiliation Services
# 1          Unknown     Taxi Affiliation Services
# 2      Credit Card                      Sun Taxi
# 3             Cash  Taxicab Insurance Agency Llc
# 5             Cash                     Flash Cab
# ...            ...                           ...
# 14372  Credit Card                  City Service
# 14373  Credit Card                   5 Star Taxi
# 14374  Credit Card     Taxi Affiliation Services
# 14375       Mobile                  City Service
# 14376  Credit Card     Taxi Affiliation Services
#
# [13066 rows x 2 columns]

# %%
taxi_trips_id = taxi_trips.merge(payment_type_master, on="payment_type")

taxi_trips_id = taxi_trips_id.merge(company_master, on="company")

# %%
taxi_trips_id.sample(5)
# Out:
#                                         trip_id  \
# 746    21758cb5a782f07d3a34fe9c9d22149426cfb87c
# 9493   9836b313dc0461a1817826bef6bb918d8bae89b3
# 5218   5c81691cf0e49242fb07697b2a52a120ddb4c82c
# 8081   f33db19053a1aa688ba7e2680701a1531b95564e
# 12388  13102414539811893b7b3280c024b294b7b3ff30
#
#                                                  taxi_id trip_start_timestamp  \
# 746    13016372e777da1289d557edbe4ce2be8a68e77bc64768...  2024-10-05 22:15:00
# 9493   f6278bee69dff0de5ec4da1ef85f90c18ce0bf54045fb9...  2024-10-05 11:45:00
# 5218   6aeb4a88ff55ac575e3ef10ef32622967534bd48fb9ba6...  2024-10-05 16:30:00
# 8081   3d183bed1b49fe5790ecd06dbc761e50c0407e2949fd74...  2024-10-05 13:15:00
# 12388  6544c8051894de482dd3253d911c3e3d713b43beb93de2...  2024-10-05 04:15:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 746   2024-10-05 22:15:00           421        0.96                         8
# 9493  2024-10-05 11:45:00           571        1.58                        32
# 5218  2024-10-05 17:30:00          3576       23.52                        76
# 8081  2024-10-05 13:30:00           452        0.98                         8
# 12388 2024-10-05 04:30:00          1235       17.74                        32
#
#        dropoff_community_area_id   fare   tips  tolls  extras  trip_total  \
# 746                           32   6.50   2.00    0.0     1.0       10.00
# 9493                          28   9.00   2.33    0.0     0.0       11.33
# 5218                           8  59.25  12.75    0.0     4.0       76.50
# 8081                          32   9.00   2.30    0.0     0.0       11.30
# 12388                         76  40.75   6.72    0.0     0.0       47.47
#
#       payment_type                       company pickup_centroid_latitude  \
# 746    Credit Card  Taxicab Insurance Agency Llc             41.892072635
# 9493        Mobile  Tac - Yellow Cab Association             41.880994471
# 5218   Credit Card  Taxicab Insurance Agency Llc              41.97907082
# 8081        Mobile                    Globe Taxi              41.89321636
# 12388       Mobile                  City Service             41.878865584
#
#       pickup_centroid_longitude dropoff_centroid_latitude  \
# 746               -87.628874157              41.884987192
# 9493              -87.632746489              41.867902418
# 5218              -87.903039661              41.892507781
# 8081               -87.63784421              41.880994471
# 12388             -87.625192142              41.980264315
#
#       dropoff_centroid_longitude datetime_for_weather  payment_type_id  \
# 746                -87.620992913  2024-10-05 22:00:00                1
# 9493               -87.642958665  2024-10-05 11:00:00                4
# 5218               -87.626214906  2024-10-05 16:00:00                1
# 8081               -87.632746489  2024-10-05 13:00:00                4
# 12388              -87.913624596  2024-10-05 04:00:00                4
#
#        company_type_id
# 746                  3
# 9493                 5
# 5218                 3
# 8081                 6
# 12388                8

# %%
taxi_trips_id.drop(["payment_type", "company"], axis=1, inplace=True)

# %%
taxi_trips_id.sample(5)
# Out:
#                                         trip_id  \
# 8525   2bf20dea5da2c4e14a5867e3cb481b0f3a885a88
# 8115   d68d692c06a7e6c0c1ccf274c0845d90ece18007
# 1624   18045d4beb127ee80443c7fa9e9819537862b302
# 10148  2b9aee1fa59bd6b2cc69fb56db8f11a76c530362
# 10813  b844ed6bee2c4680a8a17190e98bf57ce57b1733
#
#                                                  taxi_id trip_start_timestamp  \
# 8525   9c0139e741b745577a98691c70a6e8fcbbd27561f827cc...  2024-10-05 13:00:00
# 8115   279e6ef4129260b19e953938f5ca14fba369cbd6db1f06...  2024-10-05 13:15:00
# 1624   e4318a8db4098de8acda060ba7fe7ef05c240a1c81de3f...  2024-10-05 20:45:00
# 10148  93ccda8a38077612a8f32b8bf1b430f8439cf114fefb22...  2024-10-05 11:00:00
# 10813  5b45387ca7379ab00adfb0c36cef5e8b24630617f274df...  2024-10-05 10:00:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_community_area_id  \
# 8525  2024-10-05 13:00:00           480        1.00                         8
# 8115  2024-10-05 13:30:00           960        2.20                        32
# 1624  2024-10-05 20:45:00           720        7.51                        28
# 10148 2024-10-05 11:15:00           684        1.55                        32
# 10813 2024-10-05 10:45:00          2547       19.88                        76
#
#        dropoff_community_area_id   fare   tips  tolls  extras  trip_total  \
# 8525                          32   7.00   4.00    0.0     2.0       13.00
# 8115                          28  10.50   0.00    0.0     1.0       11.50
# 1624                          16  20.50   5.25    0.0     0.0       26.25
# 10148                          8   8.50   0.00    0.0     0.0        8.50
# 10813                         33  49.25  10.75    0.0     4.0       64.50
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 8525              41.892507781             -87.626214906
# 8115              41.884987192             -87.620992913
# 1624              41.874005383              -87.66351755
# 10148             41.878865584             -87.625192142
# 10813              41.97907082             -87.903039661
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 8525               41.877406123              -87.621971652
# 8115               41.867902418              -87.642958665
# 1624               41.953582125               -87.72345239
# 10148              41.899602111              -87.633308037
# 10813              41.849246754              -87.624135298
#
#       datetime_for_weather  payment_type_id  company_type_id
# 8525   2024-10-05 13:00:00                1                1
# 8115   2024-10-05 13:00:00                3                1
# 1624   2024-10-05 20:00:00                1                7
# 10148  2024-10-05 11:00:00                3                4
# 10813  2024-10-05 10:00:00                1                2

# %%
print(taxi_trips.memory_usage(deep=True).sum())
print(taxi_trips_id.memory_usage(deep=True).sum())
# Out:
# 9408023
# 7910917

# %%
payment_type_master.to_csv("payment_type_master.csv", index=False)
company_master.to_csv("company_master.csv", index=False)

# %% [markdown]
# ### Checking the modeling

# %% [markdown]
# #### Payment type

# %%
payment_type_master = taxi_trips["payment_type"].drop_duplicates().reset_index(drop=True)

payment_type_master = pd.DataFrame(
    {
        "payment_type_id": range(1, len(payment_type_master) + 1),
        "payment_type": payment_type_master
    }
)
payment_type_master
# Out:
#    payment_type_id payment_type
# 0                1  Credit Card
# 1                2      Unknown
# 2                3         Cash
# 3                4       Mobile
# 4                5       Prcard
# 5                6    No Charge
# 6                7      Dispute

# %%
new_payment_type_data = [
    {"payment_type": "Credit Card"},
    {"payment_type": "x"},
    {"payment_type": "y"}
    
]

new_payment_type_mapping = pd.DataFrame(new_payment_type_data)
new_payment_type_mapping
# Out:
#   payment_type
# 0  Credit Card
# 1            x
# 2            y

# %%
payment_type_max_id = payment_type_master["payment_type_id"].max()

# %%
range(payment_type_max_id + 1,payment_type_max_id + len(new_payment_type_mapping) + 1)
# Out:
# range(8, 11)

# %%
new_payment_type_mapping["payment_type_id"] = range(payment_type_max_id + 1,payment_type_max_id + len(new_payment_type_mapping) + 1)

new_payment_type_mapping
# Out:
#   payment_type  payment_type_id
# 0  Credit Card                8
# 1            x                9
# 2            y               10

# %%
new_payment_types = new_payment_type_mapping[~new_payment_type_mapping["payment_type"].isin(payment_type_master["payment_type"])]
new_payment_types
# Out:
#   payment_type  payment_type_id
# 1            x                9
# 2            y               10

# %%
if not new_payment_types.empty:
    payment_type_master = pd.concat([payment_type_master, new_payment_types], ignore_index=True)

# %%
payment_type_master
# Out:
#    payment_type_id payment_type
# 0                1  Credit Card
# 1                2      Unknown
# 2                3         Cash
# 3                4       Mobile
# 4                5       Prcard
# 5                6    No Charge
# 6                7      Dispute
# 7                9            x
# 8               10            y

# %% [markdown]
# #### Company

# %%
company_master = taxi_trips["company"].drop_duplicates().reset_index(drop=True)

company_master = pd.DataFrame(
    {
        "company_id": range(1, len(company_master) + 1),
        "company": company_master
    }
)
company_master.tail()
# Out:
#     company_id                      company
# 23          24                      Top Cab
# 24          25                   Setare Inc
# 25          26        Koam Taxi Association
# 26          27      2733 - 74600 Benny Jona
# 27          28  6574 - Babylon Express Inc.

# %%
new_company_data = [
    {"company": "6574 - Babylon Express Inc."},
    {"company": "x"},
    {"company": "y"}
    
]

new_company_mapping = pd.DataFrame(new_company_data)
new_company_mapping
# Out:
#                        company
# 0  6574 - Babylon Express Inc.
# 1                            x
# 2                            y

# %%
company_max_id = company_master["company_id"].max()
company_max_id
# Out:
# np.int64(28)

# %%
new_company_mapping["company_id"] = range(company_max_id + 1,company_max_id + len(new_company_mapping) + 1)

new_company_mapping
# Out:
#                        company  company_id
# 0  6574 - Babylon Express Inc.          29
# 1                            x          30
# 2                            y          31

# %%
new_companies = new_company_mapping[~new_company_mapping["company"].isin(company_master["company"])]
new_companies
# Out:
#   company  company_id
# 1       x          30
# 2       y          31

# %%
if not new_companies.empty:
    company_master = pd.concat([company_master, new_companies], ignore_index=True)

company_master.tail()
# Out:
#     company_id                      company
# 27          28  6574 - Babylon Express Inc.
# 28          30                            x
# 29          31                            y
# 30          30                            x
# 31          31                            y
